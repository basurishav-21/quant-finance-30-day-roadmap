# %%
print("setup ok")
# Out:
# setup ok

# %%
#variables
x = 5
y = 3
print(x+y)
# Out:
# 8

# %%
#a_list
nums = [1,2,3,4,5]
print(nums)
# Out:
# [1, 2, 3, 4, 5]

# %%
#a_loop
for n in nums:
    print(n * 2)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
#a_function
def add(a,b):
    return a+b

print(add(4,7))
# Out:
# 11
